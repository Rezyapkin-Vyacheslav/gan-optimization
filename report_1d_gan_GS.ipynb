# %% [markdown]
# <a href="https://colab.research.google.com/github/egorgladin/gan-optimization/blob/develop/report_1d_gan_GS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch.optim.optimizer import Optimizer
from math import ceil
"""
Gradient Sliding algorithm.

The algorithm is proposed by G. Lan in paper:
https://arxiv.org/pdf/1406.0919.pdf
and also described in his textbook:
http://pwp.gatech.edu/guanghui-lan/wp-content/uploads/sites/330/2019/08/LectureOPTML.pdf
In this code, we reference formulas from the textbook.
"""

class GradSliding(Optimizer):
    def __init__(self, params, L, M, D_tilde):
        """
        Create optimizer with specified parameters.
        
        Meaning of parameters L, M and D_tilde is explained, respectively,
        in formulas (8.1.2), (8.1.2) and Corollary 8.2. (page 497) in
        Lan's book.
        """
        defaults = dict(L=L, M=M, D_tilde=D_tilde)
        super().__init__(params, defaults)
        self.k = 0
        self.t = 0
        self.steps = 0
        self.mode = 'main'
    
    def upd_main_parameters(self):
        """
        Update parameters of main loop of gradient sliding.
        
        Increment k (counter in main loop). Change mode to PS
        (prox-sliding procedure). Calculate parameters according to the
        formulas in Lan's book:
        gamma, T, beta - formula (8.1.42); T - formula (8.1.42).
        gamma_next is value of gamma in the next iteration.
        """
        self.steps += 1
        self.k += 1
        self.mode = 'PS'

        self.gamma = 3 / (self.k + 2)
        self.gamma_next = 3 / (self.k + 3)
        
        L = self.defaults['L']
        M = self.defaults['M']
        D_tilde = self.defaults['D_tilde']
        T = ceil(M**2 * (self.k + 1)**3 / (D_tilde * L**2))
        self.T = int(T)
        
        self.P = 2 / ((self.T + 1) * (self.T + 2))
        self.beta = 9 * L * (1 - self.P) / (2 * (self.k + 1))
    
    def upd_PS_parameters(self):
        """
        Update parameters of PS procedure.
        
        Increment t (counter in PS procedure). Calculate p and theta
        according to formula (8.1.39) in Lan's book. If this is the last
        PS iteration, change mode to main and reset counter.
        """
        self.steps += 1
        self.t += 1
        self.p = self.t / 2
        self.theta = 2 * (self.t + 1) / (self.t * (self.t + 3))

    @torch.no_grad()
    def to_eval(self):
        """Load x_bar as model parameters.
        
        Recommended to do only at the beginning of main loop."""
        for group in self.param_groups:
            for par in group['params']:
                if par.grad is None:
                    continue
                state = self.state[par]
                par.copy_(state['x_bar'])

    @torch.no_grad()
    def to_train(self):
        """Load x_underbar as model parameters.
        
        Recommended to do only at the beginning of main loop."""
        for group in self.param_groups:
            for par in group['params']:
                if par.grad is None:
                    continue
                state = self.state[par]
                par.copy_(state['x_underbar'])
        
    @torch.no_grad()
    def step(self, closure=None):
        """Perform Gradient Sliding step."""
        loss = None
        if closure is not None:
            with torch.enable_grad():
                loss = closure()
        
        # Part of main loop before PS (prox-sliding) procedure.
        # In this branch, par is x_underbar in notation of Lan's book.
        if self.mode == 'main':
            self.upd_main_parameters()
            for group in self.param_groups:
                for par in group['params']:
                    if par.grad is None:
                        continue
                    
                    state = self.state[par]
                    # State initialization.
                    if len(state) == 0:
                        state['x'] = par.clone()
                        state['x_bar'] = par.clone()
                        state['x_underbar'] = par.clone()
                    
                    state['df_x'] = par.grad
                    # At the beginning of PS procedure, gradient of h
                    # will be calculated at u0 = x.
                    par.copy_(state['x'])
                
        # PS procedure.
        # In this branch, par is u in notation of Lan's book.
        elif self.mode == 'PS':
            self.upd_PS_parameters()
            for group in self.param_groups:
                for par in group['params']:
                    if par.grad is None:
                        continue
                    
                    state = self.state[par]
                    if self.t == 1:
                        state['u_tilde'] = par.clone()
                    
                    dh_u = par.grad

                    # Formula (3) from our report.
                    numerator = self.beta * (state['x'] + self.p * par) \
                              - state['df_x'] - dh_u
                    par.copy_(numerator / (self.beta * (1 + self.p)))
                    
                    state['u_tilde'] = (1 - self.theta) * state['u_tilde'] \
                                     + self.theta * par
                    
                    if self.t % self.T == 0:
                        # Finish PS procedure.
                        state['x'] = par
                        state['x_tilde'] = state['u_tilde']
                
                        # Part of main loop after PS procedure.
                        state['x_bar'] = (1 - self.gamma) * state['x_bar'] \
                                       + self.gamma * state['x_tilde']
                        # Beginning of main loop of new iteration.
                        # Now par is again x_underbar.
                        state['x_underbar'] = self.gamma_next * state['x'] \
                            + (1 - self.gamma_next) * state['x_bar']
                        par.copy_(state['x_underbar'])
            if self.t % self.T == 0:
                self.t = 0
                self.mode = 'main'
                
        return loss

# %%
import numpy as np
import torch, torch.nn as nn
import torch.nn.functional as F
from torch.optim.optimizer import Optimizer
from math import ceil
from matplotlib import pyplot as plt
from sklearn.neighbors import KernelDensity

from IPython.display import display, clear_output
import time

# from grad_sliding import GradSliding

SHIFT = 0

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

def sample_real_data(size):
    x1 = torch.randn(size, 1) * 1.5 + 9 + SHIFT
    x2 = torch.randn(size, 1) * 5.0 - 5 + SHIFT

    u = torch.rand(size, 1)
    
    return np.where(u > 0.5, x1, x2)


def plot_data(x, ax=plt, bandwidth=2.0, kernel="gaussian", xlims=(-17, 17)):
    kde = KernelDensity(bandwidth=bandwidth, kernel=kernel)
    kde.fit(x)

    x_grid = np.linspace(xlims[0], xlims[1], 1000)[:, None]
    logprob = kde.score_samples(x_grid)

    ax.set_xlim([xlims[0], xlims[1]])
    ax.plot(x_grid, np.exp(logprob))
    
    return kde

def plot_classifier(cls, kde_real, kde_fake, ax=plt, xlims=(-17, 17)):
    x_grid = np.linspace(xlims[0], xlims[1], 1000)[:, None]

    p_pred = cls(torch.from_numpy(x_grid).float().cuda()).cpu()
    
    p_real = np.exp(kde_real.score_samples(x_grid))
    p_fake = np.exp(kde_fake.score_samples(x_grid))
    
    p_bayes = p_real / (p_real + p_fake + 1e-7)
    
    ax.set_xlim([xlims[0], xlims[1]])
    ax.plot(x_grid, p_pred.detach().cpu(), 'r--')
    ax.plot(x_grid, p_bayes, 'r')

X_real = sample_real_data(10000)

ax = plt.subplot()

plot_data(X_real, ax)

plt.legend(['p(x)'])
plt.xlabel('x')
plt.ylabel('prob')

plt.show()

# %%
def calc_loss(real_preds=None, fake_preds=None, mode=''):
    if mode == 'dis':
        loss_real = -torch.log(real_preds)
        loss_fake = -torch.log(1 - fake_preds)

        loss = (loss_real + loss_fake) * 0.5
    
    elif mode == 'gen':
        loss = -torch.log(fake_preds)
    elif mode == 'main':
        loss = -torch.log(real_preds) # real preds
    elif mode == 'PS':
        loss = -torch.log(1-fake_preds) # fake preds

    return loss.mean()


def train_dis(dis, gen, dis_opt, gen_opt, batch_size, loss=calc_loss, is_train=True, mode=None):
    real_preds = None
    fake_preds = None
    
    if mode:
        pass
    elif hasattr(dis_opt, 'mode') and is_train:
        mode = dis_opt.mode
    else:
        mode = 'dis'

    if mode == 'main':
        x_real = torch.from_numpy(sample_real_data(batch_size)).float().to(DEVICE)
        real_preds = dis(x_real)

    elif mode == 'PS':
        z = torch.randn(batch_size, 1).to(DEVICE)
        x_fake = gen(z)
        fake_preds = dis(x_fake.detach())

    elif mode == 'dis':
        x_real = torch.from_numpy(sample_real_data(batch_size)).float().to(DEVICE)
        real_preds = dis(x_real)
        z = torch.randn(batch_size, 1).to(DEVICE)
        x_fake = gen(z)
        fake_preds = dis(x_fake.detach())

    # Discriminator losses
    if is_train:
        loss_D = loss(real_preds=real_preds, fake_preds=fake_preds, mode=mode)
    else:
        with torch.no_grad():
            loss_D = loss(real_preds=real_preds, fake_preds=fake_preds, mode=mode)

    if is_train:
        # Discriminator step
        dis_opt.zero_grad()
        loss_D.backward()
        dis_opt.step()

    return loss_D.item()

def train_gen(dis, gen, dis_opt, gen_opt, batch_size, loss = calc_loss):
    # Forward fake
    z = torch.randn(batch_size, 1).cuda()
    x_fake = gen(z)

    fake_preds = dis(x_fake)

    # Generator losses
    loss_G = loss(fake_preds=fake_preds, mode='gen')

    # Generator step
    gen_opt.zero_grad()
    loss_G.backward()
    gen_opt.step()

    return loss_G.item()

# Generator is an MLP that converts noise into output data


def make_lin_relu_gen():
    gen = nn.Sequential(
        nn.Linear(1, 32),
        nn.ReLU(),
        nn.Linear(32, 32),
        nn.ReLU(),
        nn.Linear(32, 32),
        nn.ReLU(),
        nn.Linear(32, 1),
    )
    return gen

def make_lin_relu_dis():
    # Discriminator is mirroring the architecture of the generator
    dis = nn.Sequential(
        nn.Linear(1, 32),
        nn.ReLU(),
        nn.Linear(32, 32),
        nn.ReLU(),
        nn.Linear(32, 32),
        nn.ReLU(),
        nn.Linear(32, 1),
        nn.Sigmoid()
    )
    return dis

def train_1d_gan(dis, gen, dis_opt, gen_opt, train_dis=train_dis, loss=calc_loss, n_iters=100, n_D_iters=1, batch_size=128, eval_freq=10, print_losses=False, mode=None):
    losses_D_hist = []
    losses_G_hist = []
    
    SLIDING = hasattr(dis_opt, 'mode') and (mode != 'dis')

    for i in range(1, n_iters):

        if SLIDING and i > 0:
            dis_opt.to_train()
        
        T = 0  
        while True:
            T += 1
            loss_D = train_dis(dis, gen, dis_opt, gen_opt, batch_size=batch_size, loss=loss, is_train=True, mode=mode)
            if print_losses:
                print(f'D_loss: {loss_D:.3f}')
            if SLIDING and dis_opt.mode == 'main':
                dis_opt.to_eval()
                # calc full loss
                loss_D = train_dis(dis, gen, dis_opt, gen_opt, batch_size=batch_size, loss=loss, is_train=False)
                break
            elif ((not SLIDING) or (mode == 'dis')) and T == n_D_iters:
                break

        for _ in range(T):
            loss_G = train_gen(dis, gen, dis_opt, gen_opt, batch_size=batch_size, loss=loss)
        if print_losses:
            print(f'G_loss: {loss_G:.3f}')
        
        losses_D_hist.append(loss_D)
        losses_G_hist.append(loss_G)

        if i % eval_freq == 0:


            clear_output(True)
            fig, axes = plt.subplots(ncols=3, figsize=(25, 5))

            X_real = sample_real_data(10000)
            X_fake = gen(torch.randn(10000, 1).cuda()).detach().cpu().numpy()

            kde_real = plot_data(X_real, axes[0])
            kde_fake = plot_data(X_fake, axes[0])
            axes[0].legend(['p_real', 'q_fake'])
            axes[0].set_ylabel('p(x), distribution')
            axes[0].set_xlabel('x')

            plot_classifier(dis, kde_real, kde_fake, axes[1])
            axes[1].legend(['p_dis', 'p_bayes'])
            axes[1].set_ylabel('p(x), clf')
            axes[1].set_xlabel('x')

            axes[2].plot(losses_D_hist)
            axes[2].plot(losses_G_hist)
            axes[2].set_ylim([0, 2.5])
            axes[2].legend(['loss_D', 'loss_G'])
            axes[2].set_ylabel('Loss')
            axes[2].set_xlabel('Iterations')

            
            plt.show()

            display(f'n_iter: {i}, loss_D: {np.mean(losses_D_hist[-eval_freq:]):.3f}, loss_G: {np.mean(losses_G_hist[-eval_freq:]):.3f}, T: {T}')

# %%
from IPython.display import clear_output

# train discriminator to detect positive numbers
L = 0.3 * 100
M = 4.8 * 10
D_tilde = 317.02
model = nn.Sequential(nn.Linear(1, 1, bias=False), nn.Sigmoid()).to(DEVICE)
opt = GradSliding(model.parameters(), L=L, M=M, D_tilde=D_tilde)
opt = torch.optim.SGD(model.parameters(), lr=1e-2, )

steps = []
loss_pos = []
loss_neg = []

for i in range(10000):
    mode = getattr(opt, 'mode') if hasattr(opt, 'mode') else np.random.choice(['main', 'PS'])
    if mode == 'main':
        x = torch.rand(10, 1).cuda()  # positive
        y_pred = model(x)
        loss = -torch.log(y_pred).mean()
    elif mode == 'PS':
        x = torch.rand(10, 1).cuda() - 1  # negative
        y_pred = model(x)
        loss = -torch.log(1 - y_pred).mean()
    
    opt.zero_grad()
    loss.backward()
    opt.step()
    
    # Calculate full loss.
    if i == 0 or mode == 'main':
        if hasattr(opt, 'mode'):
            opt.to_eval()
        with torch.no_grad():
            x1 = torch.rand(10, 1).cuda()  # positive
            x2 = torch.rand(10, 1).cuda() - 1  # negative
            y_pred1 = model(x1)
            y_pred2 = model(x2)
            loss_pos.append(-torch.log(y_pred1).mean().item())
            loss_neg.append(-torch.log(1 - y_pred2).mean().item())
            if hasattr(opt, 'mode'):
                steps.append(opt.steps)
            else:
                steps.append(i)
        if hasattr(opt, 'mode'):
            opt.to_train()
        if i % 50 == 0:
            clear_output(True)

            fig, axes = plt.subplots(ncols=3, figsize=(25, 5))

            X_real = np.random.rand(1000, 1)
            X_fake = np.random.rand(1000, 1) - 1
            kde_real = plot_data(X_real, axes[0], 0.1, "tophat", (-1.5, 1.5))
            kde_fake = plot_data(X_fake, axes[0], 0.1, "tophat", (-1.5, 1.5))
            axes[0].legend(['p_pos', 'q_neg'])

            if hasattr(opt, 'mode'):
                opt.to_eval()
            plot_classifier(model, kde_real, kde_fake, axes[1], (-1.5, 1.5))
            axes[1].legend(['p_dis', 'p_bayes'])

            axes[2].plot(steps, loss_pos, label="loss_pos")
            axes[2].plot(steps, loss_neg, label="loss_neg")

            plt.legend()
            plt.show()

# %% [markdown]
# Adam

# %%
# experiment with Adam optimizer

gen = make_lin_relu_gen().to(DEVICE)
dis = make_lin_relu_dis().to(DEVICE)

gen_opt = torch.optim.Adam(gen.parameters(), lr=1e-3, betas=(0.0, 0.999))
dis_opt = torch.optim.Adam(dis.parameters(), lr=1e-3, betas=(0.0, 0.999))

train_1d_gan(dis, gen, dis_opt, gen_opt, loss = calc_loss, n_iters=2001, n_D_iters=1, batch_size=128, eval_freq=200)
# Out:
# 'n_iter: 2000, loss_D: 0.694, loss_G: 0.694, T: 1'

# %% [markdown]
# OK

# %% [markdown]
# GradSliding with the same $f$ and $h$

# %%
gen = make_lin_relu_gen().to(DEVICE)
dis = make_lin_relu_dis().to(DEVICE)

gen_opt = torch.optim.Adam(gen.parameters(), lr=1e-3, betas=(0.0, 0.999))
dis_opt = GradSliding(dis.parameters(), L=10, M=100, D_tilde=100)

train_1d_gan(dis, gen, dis_opt, gen_opt, loss=calc_loss, n_iters=1501, n_D_iters=1, batch_size=128, eval_freq=200, mode='dis')
# Out:
# 'n_iter: 1400, loss_D: 0.656, loss_G: 0.743, T: 1'

# %% [markdown]
# OK

# %% [markdown]
# Adam with $f$ as real discriminator loss and $h$ as fake discriminator loss

# %%
gen = make_lin_relu_gen().to(DEVICE)
dis = make_lin_relu_dis().to(DEVICE)

gen_opt = torch.optim.Adam(gen.parameters(), lr=1e-3, betas=(0.0, 0.999))
dis_opt = GradSliding(dis.parameters(), L=10, M=100, D_tilde=100)

train_1d_gan(dis, gen, dis_opt, gen_opt, loss=calc_loss, n_iters=301, n_D_iters=1, batch_size=128, eval_freq=5)
# Out:
# 'n_iter: 10, loss_D: 4.308, loss_G: 3.898, T: 1332'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-385eb25526a6> in <module>()
#       5 dis_opt = GradSliding(dis.parameters(), L=10, M=100, D_tilde=100)
#       6
# ----> 7 train_1d_gan(dis, gen, dis_opt, gen_opt, loss=calc_loss, n_iters=301, n_D_iters=1, batch_size=128, eval_freq=5)
#
# <ipython-input-7-f5eecc80c99b> in train_1d_gan(dis, gen, dis_opt, gen_opt, train_dis, loss, n_iters, n_D_iters, batch_size, eval_freq, print_losses, mode)
#     130
#     131         for _ in range(T):
# --> 132             loss_G = train_gen(dis, gen, dis_opt, gen_opt, batch_size=batch_size, loss=loss)
#     133         if print_losses:
#     134             print(f'G_loss: {loss_G:.3f}')
#
# <ipython-input-7-f5eecc80c99b> in train_gen(dis, gen, dis_opt, gen_opt, batch_size, loss)
#      71     gen_opt.zero_grad()
#      72     loss_G.backward()
# ---> 73     gen_opt.step()
#      74
#      75     return loss_G.item()
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      13         def decorate_context(*args, **kwargs):
#      14             with self:
# ---> 15                 return func(*args, **kwargs)
#      16         return decorate_context
#      17
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/adam.py in step(self, closure)
#     109                 step_size = group['lr'] / bias_correction1
#     110
# --> 111                 p.addcdiv_(exp_avg, denom, value=-step_size)
#     112
#     113         return loss
#
# KeyboardInterrupt:

# %% [markdown]
# Algoritm shows disconvergence
